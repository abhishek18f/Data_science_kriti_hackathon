# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime
from sklearn.preprocessing import LabelEncoder

# %%
train = pd.read_csv('data/training_data.csv') 
test = pd.read_csv('data/testing_data.csv')
pd.set_option('max_column' , 40)
pd.set_option('max_rows'  ,000)
train.head()
# Out:
#    Unnamed: 0  ID  Salary           JobCity Gender         DOB  10percentage  \
# 0           0   0  200000         Bangalore      m  1990-01-15          55.5
# 1           1   1  190000           Chennai      m  1990-11-02          83.0
# 2           2   2  335000  Chennai & Mumbai      m  1991-07-31          81.2
# 3           3   3  325000             Noida      m  1990-07-16          85.0
# 4           4   4  360000           Chennai      m  1991-07-14          89.9
#
#        10board  12graduation  12percentage      12board  CollegeID  \
# 0  state board        2007.0          52.5  state board         44
# 1  state board           NaN          86.0  state board      11473
# 2         cbse        2008.0          75.4         cbse       2795
# 3         cbse        2008.0          68.6         cbse       5232
# 4  state board           NaN          84.5  state board       8524
#
#    CollegeTier       Degree                             Specialization  \
# ...

# %%
r = train['CollegeID'].value_counts()
with pd.option_context('display.max_rows', None, 'display.max_columns', None): print(r) # more options can be specified also
# Out:
# 272      59
# 64       28
# 11759    28
# 44       26
# 55       23
# 47       23
# 350      22
# 6874     20
# 3076     19
# 429      18
# 10932    16
# 285      15
# 8195     15
# 1622     15
# 347      14
# 7376     14
# 184      13
# 51       13
# 222      13
# 124      13
# 4948     13
# 3427     12
# 75       12
# 172      12
# 57       12
# 3579     12
# 66       11
# 35       11
# 9769     11
# 7557     11
# 4971     11
# 1866     11
# 9019     10
# 547      10
# 1141     10
# 11368    10
# 13       10
# 6196     10
# 3801      9
# 8297      9
# 1638      9
# 2563      9
# 1906      9
# 5818      9
# 8818      9
# 462       9
# 48        9
# 144       8
# 198       8
# 3879      8
# 115       8
# 14004     8
# 182       8
# 5904      8
# 5026      8
# 127       8
# 137       8
# 2066      8
# 8888      8
# 13210     8
# 387       8
# 893       8
# 4450      8
# 1263      8
# 1428      8
# 9737      7
# 8819      7
# 400       7
# 974       7
# 1436      7
# 2819      7
# ...

# %%
    p = test['CollegeID'].value_counts()
    with pd.option_context('display.max_rows', None, 'display.max_columns', None): print(p) # more options can be specified also
# Out:
# 272      35
# 64       10
# 47       10
# 350       9
# 44        9
# 3801      8
# 6874      8
# 4042      7
# 11759     7
# 51        6
# 66        6
# 167       6
# 55        6
# 165       6
# 184       6
# 356       6
# 75        6
# 4501      6
# 11788     5
# 1866      5
# 23        5
# 3076      5
# 4948      5
# 485       5
# 4234      4
# 4971      4
# 347       4
# 439       4
# 13210     4
# 4450      4
# 5015      4
# 2921      4
# 222       4
# 285       4
# 1920      4
# 429       4
# 6638      4
# 462       4
# 11630     4
# 5111      4
# 8195      4
# 13        4
# 7814      4
# 14382     4
# 48        4
# 124       4
# 9837      4
# 9481      4
# 7376      4
# 5904      4
# 3579      4
# 1906      3
# 275       3
# 5400      3
# 13594     3
# 6566      3
# 2819      3
# 7542      3
# 9737      3
# 3716      3
# 403       3
# 568       3
# 1622      3
# 3879      3
# 903       3
# 10932     3
# 6408      3
# 198       3
# 119       3
# 137       3
# 4368      3
# ...

# %%
r = train['CollegeCityID'].value_counts()
with pd.option_context('display.max_rows', None, 'display.max_columns', None): print(r) # more options can be specified also
# Out:
# 272.0      55
# 11759.0    26
# 44.0       25
# 64.0       25
# 350.0      21
# 55.0       21
# 6874.0     20
# 47.0       20
# 3076.0     19
# 429.0      17
# 10932.0    16
# 285.0      15
# 8195.0     14
# 1622.0     14
# 124.0      13
# 4948.0     13
# 3579.0     12
# 51.0       12
# 222.0      12
# 75.0       12
# 347.0      12
# 184.0      12
# 3427.0     12
# 7376.0     12
# 172.0      11
# 9769.0     11
# 66.0       11
# 35.0       11
# 7557.0     10
# 1141.0     10
# 6196.0     10
# 547.0      10
# 57.0       10
# 11368.0    10
# 4971.0     10
# 3801.0      9
# 1866.0      9
# 9019.0      9
# 8818.0      9
# 1906.0      9
# 462.0       8
# 1638.0      8
# 4450.0      8
# 5904.0      8
# 115.0       8
# 182.0       8
# 3879.0      8
# 1428.0      8
# 48.0        8
# 5026.0      8
# 387.0       8
# 893.0       8
# 5818.0      8
# 1263.0      8
# 127.0       8
# 198.0       8
# 2066.0      8
# 13.0        8
# 137.0       7
# 1436.0      7
# 4889.0      7
# 5812.0      7
# ...

# %%
r = test['CollegeCityID'].value_counts()
with pd.option_context('display.max_rows', None, 'display.max_columns', None): print(r) # more options can be specified also
# Out:
# 272.0      34
# 47.0       10
# 44.0        9
# 350.0       9
# 64.0        9
# 3801.0      8
# 6874.0      7
# 4042.0      7
# 51.0        6
# 165.0       6
# 167.0       6
# 11759.0     6
# 55.0        6
# 4501.0      6
# 184.0       6
# 66.0        6
# 75.0        6
# 356.0       6
# 11788.0     5
# 1866.0      5
# 485.0       5
# 23.0        5
# 3076.0      5
# 11630.0     4
# 5904.0      4
# 429.0       4
# 462.0       4
# 7376.0      4
# 347.0       4
# 8195.0      4
# 4971.0      4
# 4948.0      4
# 285.0       4
# 6638.0      4
# 5111.0      4
# 13.0        4
# 9481.0      4
# 9837.0      4
# 3579.0      4
# 13210.0     4
# 4234.0      4
# 5015.0      4
# 222.0       4
# 4368.0      3
# 1906.0      3
# 903.0       3
# 48.0        3
# 4450.0      3
# 7077.0      3
# 3879.0      3
# 2952.0      3
# 7542.0      3
# 1622.0      3
# 14351.0     3
# 275.0       3
# 5400.0      3
# 3716.0      3
# 9737.0      3
# 13594.0     3
# 2921.0      3
# 439.0       3
# 57.0        3
# ...
