# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime
from sklearn.preprocessing import LabelEncoder

# %%
train = pd.read_csv('data/training_data.csv') 
test = pd.read_csv('data/testing_data.csv')
train.head()
# Out:
#    Unnamed: 0  ID  Salary           JobCity Gender         DOB  10percentage  \
# 0           0   0  200000         Bangalore      m  1990-01-15          55.5
# 1           1   1  190000           Chennai      m  1990-11-02          83.0
# 2           2   2  335000  Chennai & Mumbai      m  1991-07-31          81.2
# 3           3   3  325000             Noida      m  1990-07-16          85.0
# 4           4   4  360000           Chennai      m  1991-07-14          89.9
#
#        10board  12graduation  12percentage  ... ComputerScience  \
# 0  state board        2007.0          52.5  ...              -1
# 1  state board           NaN          86.0  ...              -1
# 2         cbse        2008.0          75.4  ...             500
# 3         cbse        2008.0          68.6  ...              -1
# 4  state board           NaN          84.5  ...              -1
#
#    MechanicalEngg  ElectricalEngg TelecomEngg CivilEngg  conscientiousness  \
# 0              -1              -1          -1        -1                NaN
# 1              -1              -1         313        -1            -0.1590
# 2              -1              -1          -1        -1            -1.0208
# 3              -1              -1          -1        -1            -0.9969
# 4              -1              -1          -1        -1             1.2772
#
#    agreeableness  extraversion nueroticism  openess_to_experience
# 0        -0.6201       -0.1437      0.9066                -1.6273
# 1         0.8784        0.7785      0.1459                 1.2470
# 2        -1.1196       -0.6048      0.5262                 0.2889
# 3         0.0328       -0.3440      0.7086                -1.2354
# 4         0.8784        0.4711     -0.7415                 0.4805
#
# [5 rows x 36 columns]

# %% [markdown]
# # DATA ANALYSIS

# %%
#print(train['10board'].unique)
columns = train.columns.tolist()
for column in columns:
    print(column + ":")
    print(train[column].unique())
# Out:
# Unnamed: 0:
# [   0    1    2 ... 2997 2998 2999]
# ID:
# [   0    1    2 ... 2997 2998 2999]
# Salary:
# [ 200000  190000  335000  325000  360000  100000 1200000  705000  420000
#   700000  480000  240000  775000  515000  650000  350000  395000  260000
#   150000  600000  115000  250000  320000   95000  470000  460000  280000
#   345000  445000  180000  440000 3000000  220000  215000  300000  120000
#   485000  145000  270000  315000  370000  630000  330000  305000  310000
#   295000  450000  400000  430000  105000  265000  730000  500000  555000
#   415000  550000  505000  340000  160000  375000  275000   60000  135000
#   205000  225000  170000  210000  365000  140000  195000  620000  455000
#    85000  110000  290000  235000  405000  390000  245000  930000  435000
#   385000  255000  950000  560000  230000   70000  640000  185000  425000
#   175000   80000  565000   75000  155000  715000  610000  880000  725000
#   355000  165000 1000000  675000   50000  530000   90000 1320000  410000
#   660000  510000  380000  490000 1500000  800000 1100000  285000  615000
#   495000  860000 2600000  520000  130000  125000 2050000  845000 1800000
#   575000  570000  820000  720000   35000 3500000  850000   65000  465000
#   540000  655000  690000  810000  525000  625000  475000  144000 2300000
#   590000 1300000   40000  785000  755000   45000 1030000  925000  585000
#   750000   55000  645000  545000  760000 1745000 2020000  580000  900000
#   605000 1110000  535000  680000 2000000]
# JobCity:
# ['Bangalore' 'Chennai' 'Chennai & Mumbai' 'Noida' 'kolhapur' 'hyderabad'
#  'New Delhi' 'Navi Mumbai' 'Mumbai' 'sampla' 'Dammam' '-1' 'Rewari' 'Pune'
#  'Kolkata' 'Lucknow' 'Gurgaon' 'Faridabad' 'Jodhpur' 'Indore' 'Jaipur'
#  'Bathinda' 'Hyderabad' 'Mysore' 'Greater Noida' 'noida' 'Patna' 'mohali'
#  'Rourkela' 'CHENNAI' 'Ernakulam' 'Bangalore ' 'Bhubaneshwar' 'pune'
#  'Coimbatore' 'Banglore' 'bangalore' 'Unnao' 'Bhubaneswar' 'Siliguri '
#  'Delhi' 'indore' 'Neemrana' 'Bhopal' 'muzzafarpur' 'Ongole' 'jaipur'
#  'Shahdol' 'Trivandrum' 'Pondicherry' ' Pune' 'jAipur' 'Madurai '
#  'Bahadurgarh' 'Vellore' 'Thane' 'Bilaspur' 'Rajasthan' 'Mangalore'
#  'Vijayawada' 'mumbai' 'Karnal' 'Kochi' 'pune ' 'Hyderabad ' 'Ghaziabad'
#  'Nashik' 'Pune ' 'Greater noida' 'Chandigarh' 'Nasikcity' 'Haldia'
#  'KOLKATA' 'Rajkot' 'Bengaluru' 'Gurgaon ' ' Delhi' 'Muzaffarpur'
#  'ghaziabad' 'Aurangabad' 'Roorkee' 'Muzaffarnagar' 'karnal' 'Dubai'
#  'chennai' 'BANGALORE ' 'udaipur' 'Ahmedabad' 'Tornagallu' 'gurgoan'
#  'Dehradun' 'trivandrum' 'HYDERABAD' 'hyderabad(bhadurpally)' ' Mumbai'
#  'Agra' 'Chennai ' 'Beawar' 'PUNE' 'Gonda' 'Siliguri' 'Raipur' 'bihar'
#  'Visakhapatnam' 'TRIVANDRUM' 'Kanpur' 'GURGOAN' 'Belgaum' 'bhubaneswar'
#  'kudankulam ,tarapur' 'Pilani' 'Dharmapuri' 'Madurai' 'Noida ' 'Phagwara'
#  'Chennai, Bangalore' 'Trichy' 'Kochi/Cochin' 'new delhi' 'Hubli'
#  'Kolkata`' 'gurgaon' 'Chandrapur' 'Hissar' 'Ahmednagar' 'Nagpur'
#  'kolkata' 'Bareli' 'Banagalore' 'AM' 'Thiruvananthapuram' 'THANE'
#  'Jamshedpur' 'Mysore ' 'Ambala' 'Jeddah Saudi Arabia' 'kharagpur'
#  'vsakhapttnam' 'sonepat' 'patna' 'Surat' 'Chandigarh ' 'Gandhi Nagar'
#  'Tirupati' 'Jalandhar' 'Mettur, Tamil Nadu ' 'new delhi - jaisalmer'
#  'Haridwar' 'New Delhi ' 'Alwar' 'Durgapur' 'Australia' ' bangalore'
#  'Jabalpur' 'Khopoli' 'delhi' 'Muvattupuzha' 'Sonipat' 'ranchi' 'haryana'
#  'Nagpur ' 'Dhanbad' 'Gandhinagar' 'Bulandshahar' 'new dehli' 'Ranchi'
#  'Jhansi' 'kala amb ' 'Mohali' 'keral' 'RAE BARELI' 'Howrah' 'NOIDA'
#  'Rohtak' 'Asansol' 'Burdwan' 'banglore' 'Tirupathi' 'Dharuhera'
#  'dehradun' 'Jaspur' 'Kalmar, Sweden' 'bengaluru' 'Mumbai ' 'coimbatore'
#  'Secunderabad' 'Tirunelvelli' 'Ganjam' 'Ranchi ' 'Baroda' 'LUCKNOW'
#  'manesar' 'Pantnagar' 'Miryalaguda' 'CHEYYAR' 'vizag'
#  'Kochi/Cochin, Chennai and Coimbatore' 'Bankura' 'GURGAON' 'Maharajganj'
#  ' Chennai' 'Rayagada, Odisha' 'punr' 'Banglore ' 'Asifabadbanglore'
#  'PATNA' 'Greater NOIDA' 'DELHI' 'GURAGAON' 'SHAHDOL' 'Gorakhpur'
#  'Rajpura' 'Karad' 'Punchkula' 'lucknow' 'MEERUT' 'thane'
#  'latur (Maharashtra )' 'Delhi/NCR' 'Sahibabad' 'Bundi' 'Dharamshala'
#  'Jaipur ' 'Nanded' 'Shimla' 'Baddi HP' 'NEW DELHI' 'Bhiwadi' 'Bhagalpur'
#  'Ludhiana' 'Gurga' 'Jagdalpur' 'Baripada' 'pondi' 'Johannesburg'
#  'Bharuch' 'Panchkula' 'Bikaner' 'chandigarh' 'VIZAG' 'bangalore '
#  'Ahmedabad ' 'GREATER NOIDA' 'Bhubneshwar' 'kanpur' 'ncr' 'vapi' 'BHOPAL'
#  'Navi mumbai' 'Trichur' 'hderabad' 'Bhubaneswar ' 'BANGALORE'
#  'Trivandrum ' 'Jhajjar' 'Nalagarh' 'Yamuna Nagar' 'Calicut' 'angul'
#  'KANPUR' 'Kanpur ' 'Daman and Diu' ' ariyalur' 'Patiala' 'mysore'
#  'SADULPUR,RAJGARH,DISTT-CHURU,RAJASTHAN' 'noida ' 'Manesar' 'Nellore'
#  'mumbai ' 'Al Jubail,Saudi Arabia' 'Guwahati' 'raipur' 'Mainpuri'
#  'Bhopal ' 'Gurgoan' 'Jowai']
# Gender:
# ['m' 'f']
# DOB:
# ['1990-01-15' '1990-11-02' '1991-07-31' ... '1988-11-27' '1992-10-15'
#  '1988-10-07']
# 10percentage:
# [55.5  83.   81.2  85.   89.9  76.93 87.   92.8  90.   72.   89.   91.
#  89.92 68.4  87.4  93.33 86.6  77.5  78.   80.53 72.8  49.9    nan 77.8
#  84.62 80.   88.4  73.   64.   80.33 86.8  52.5  71.6  87.2  76.   74.
#  63.   91.8  80.2  86.4  75.   86.   80.64 78.2  76.5  75.6  87.5  81.6
#  77.4  83.6  82.6  73.2  92.3  79.   74.67 84.2  81.92 93.   92.   58.
#  45.6  87.6  73.5  67.25 79.4  62.26 94.16 75.2  91.6  85.17 84.   67.33
#  63.4  79.6  66.4  57.78 84.5  80.13 82.   58.33 87.3  71.2  95.4  82.8
#  58.17 80.5  77.   69.   76.17 88.88 68.5  68.   63.5  68.6  93.6  78.8
#  62.34 58.5  65.5  81.   74.5  60.14 72.33 67.   84.6  81.8  67.8  74.6
#  85.62 77.88 77.2  92.2  66.85 75.33 77.6  88.   49.   71.73 70.   65.8
#  93.3  91.5  86.62 74.8  62.   85.8  88.3  87.73 50.66 76.4  82.28 83.3
#  88.6  79.8  75.4  67.2  78.67 78.5  88.7  93.2  84.8  65.   69.17 88.57
#  67.5  55.   86.3  84.75 50.   78.6  80.6  68.14 65.17 93.4  85.6  90.1
#  89.76 55.6  71.1  86.66 61.   95.52 71.   88.2  87.68 74.23 64.48 78.57
#  77.66 67.16 67.17 87.07 72.45 93.38 78.83 51.   78.72 91.17 53.   71.76
#  74.3  77.65 87.87 79.86 81.46 66.33 90.83 53.6  91.33 70.83 89.25 92.93
#  73.73 77.83 93.07 77.33 70.61 60.8  86.16 85.18 54.6  83.43 56.78 84.16
#  73.37 85.73 73.66 92.66 62.93 93.94 55.3  54.4  71.67 66.66 72.16 74.2
#  59.2  63.2  65.3  70.56 57.5  75.06 70.16 77.53 89.44 69.83 60.66 95.6
#  79.28 73.07 80.32 67.3  72.83 72.75 93.43 66.3  61.75 70.75 86.15 85.3
#  83.14 81.38 51.36 86.33 69.54 94.7  82.24 76.64 64.6  97.   56.16 64.2
#  79.29 66.67 83.67 75.67 71.83 65.1  78.88 43.   46.8  75.66 71.13 81.3
#  88.53 71.06 70.08 95.86 61.9  63.43 94.43 92.32 80.42 87.23 62.3  83.1
#  85.38 66.16 64.66 92.1  58.4  78.66 80.46 80.88 77.78 67.67 78.17 86.53
#  89.56 57.7  60.5  94.1  52.93 88.17 82.67 87.83 69.92 77.16 61.1  94.72
#  89.42 75.71 76.16 46.   69.73 89.17 97.76 72.17 53.06 60.1  91.62 51.42
#  85.53 48.8  80.63 71.85 54.83 86.88 65.41 79.75 69.1  76.33 88.66 46.24
#  74.62 56.2  84.43 95.54 86.14 64.8  59.57 70.4  73.67 71.05 60.7 ]
# 10board:
# ['state board' 'cbse' '0' 'tamilnadu state board' 'karnataka state board'
#  'icse' 'board of secondary education' 'up board' 'rbse' 'maharashtra'
#  'ssc' 'hse' 'ssc maharashtra board' 'kerala state board' 'bse' 'wbbse'
#  'sslc board' 'up' 'up board,allahabad' 'mp board' 'rajasthan board'
#  'bse, odisha' 'matriculation' 'biharboard'
#  'west bengal board of secondary eucation'
#  'central board of secondary education' 'maharashtra state board' 'state'
#  'maharashtra state board for ssc' 'kolhapur' 'mp' 'state board '
#  'bse(board of secondary education)' 'maharashtra nasik board' 'sslc'
#  'hbsc' 'haryana board of school education' 'up board , allahabad'
#  'uttar pradesh board' 'stmary higher secondary'
#  'karantaka secondary education and examination borad'
#  'maharashtra state(latur board)'
#  'karnataka secondary education examination board'
#  'jharkhand acedemic council' 'kseeb' 'state board (jac, ranchi)'
#  'j & k bord' 'icse board , new delhi' 'ssc-andhra pradesh'
#  'central board of secondary education, new delhi' 'hse,orissa'
#  'board of secondary school education' 'gujarat state board' 'upboard'
#  'maharashtra state board pune' 'maharashtra board' 'mpbse' 'stateboard'
#  'stjoseph of cluny matrhrsecschool,neyveli,cuddalore district'
#  'karnataka board' 'karnataka state secondary education board' 'bsepatna'
#  'cbse board' 'kerala university'
#  'board of secondary education,rajasthan(rbse)' 'cgbse'
#  'sri kannika parameswari highier secondary school, udumalpet'
#  'secondary school education' 'uttaranchal state board'
#  'jharkhand secondary examination board (ranchi)'
#  'kerala state technical education' 'dav public school sec 14' 'metric'
#  'punjab school education board, mohali' 'secondary school certificate'
#  'karnataka' 'ms board' 'bright way college, (up board)'
#  'board of school education harayana' 'jkbose' 'bseb' 'bse,odisha'
#  'bseb patna' 'rajasthan board of secondary education'
#  'board of secondary education rajasthan' 'tn state board' 'pseb'
#  'dav public school,hehal' 'karnataka secondary education board'
#  'karnataka secondary board' 'matric'
#  'board of secondary education,andhra pradesh'
#  'west bengal board of secondary education' 'maharastra board'
#  'bseb,patna' 'gyan bharati school' 'hsc' 'anglo indian'
#  'madhya pradesh board' 'maharashtra board, pune'
#  'j&k state board of school education' 'nagpur'
#  'board of school education uttarakhand'
#  'maharashtra state board mumbai divisional board' 'bsc,orissa'
#  'uttarakhand board' 'nagpur board' 'secondary school of education'
#  "stmary's convent inter college" 'board secondary  education' 'mhsbse'
#  'board of  secondary education' 'jharkhand accademic council'
#  'don bosco maatriculation school' 'board of secondary education orissa'
#  'matric board' 'cbse ' 'karnataka state education examination board' 'ua'
#  'cluny' 'board of secendary education orissa' 'ksseb' 'latur board'
#  'board of secondary education - andhra pradesh' 'hbse' 'bihar'
#  'state bord' 'cicse' 'board of secondary education, andhra pradesh'
#  'up(allahabad)' 'bse,orissa' 'nagpur divisional board'
#  'ksseb(karnataka state board)' 'icse board' 'matriculation board'
#  'bihar board' 'board of ssc education andhra pradesh'
#  'maharashtra state board of secondary & higher secondary education'
#  'jharkhand secondary examination board,ranchi' 'gseb'
#  'kseeb(karnataka secondary education examination board)' 'cgbse raipur'
#  'uttar pradesh' 'cbse[gulf zone]' 'mpboard' 'aisse'
#  'tamilnadu matriculation board' 'pune board'
#  'bihar school examination board'
#  'uttaranchal shiksha avam pariksha parishad' 'apssc'
#  'holy cross matriculation hr sec school' 'andhra pradesh state board'
#  'karnataka board of higher education' 'tamil nadu state' 'up-board'
#  'maharashtra state boar of secondary and higher secondary education'
#  'board of secondaray education' 'state board of karnataka'
#  'bihar examination board, patna'
#  'maharashtra state board of secondary and higher secondary education,pune'
#  'stjosephs girls higher sec school,dindigul'
#  'board ofsecondary education,ap' 'karnataka education board'
#  'jharkhand secondary education board' 'pune'
#  'maharashtra state board of secondary and higher secondary education'
#  'state board of secondary education, ap' 'bseb, patna'
#  'karnataka secondory education board'
#  'council for indian school certificate examination' 'hsce'
#  'bihar secondary education board,patna' 'board of ssc' 'mp board bhopal'
#  'latur' 'apsche' 'msbshse,pune'
#  'state board of secondary education( ssc)'
#  'school secondary education, andhra pradesh' 'uttranchal board' 'bsemp'
#  'gsheb' 'nagpur board,nagpur' 'education board of kerala' 'u p board'
#  'seba(assam)' 'seba' 'rajasthan board ajmer' 'kseb'
#  'board of secondary education, rajasthan'
#  'himachal pradesh board of school education'
#  'state board - west bengal board of secondary education : wbbse'
#  'up baord' 'rbse,ajmer' 'ghseb' 'gujarat board' 'ssc regular' 'kea'
#  'upbhsie' 'karnataka sslc board bangalore' 'u p' 'jbse,jharkhand'
#  'board of secondary education (bse) orissa' 'nasik' 'jseb'
#  'karnataka education board (keeb)' 'sarada high scchool'
#  'jawahar navodaya vidyalaya' 'board of secondary education(bse) orissa'
#  'karnataka state examination board' 'mumbai board'
#  'karnataka secondary education' 'nashik board' 'mp-bse'
#  'secondary state certificate' 'maharashtra state board,pune'
#  'board of intermediate' 'up board' 'icse' 'rbse' 'maharashtra'
#  'msbte (diploma in computer technology)' 'chse' 'hsc maharashtra board'
#  'kerala state board' 'wbscte' 'wbchse' 'pue' 'isc' 'bie' 'up'
#  'up board,allahabad' 'mp board' 'rajasthan board'
#  'board of secondary education rajasthan' 'chse, odisha' 'bice' 'mp'
#  'upboard' 'west bengal council of higher secondary eucation'
#  'diploma in engg (e &tc) tilak maharashtra vidayapeeth'
#  'maharashtra state board' 'state' 'board of intermediate education'
#  'maharashtra state board for hsc' 'kolhapur' 'state board '
#  'chse(concil of higher secondary education)' 'maharashtra nasik board'
#  'puc' 'intermediate board' 'intermediate' 'technical board, punchkula'
#  'up board , allahabad' 'uttar pradesh board' 'ipe' 'nios' 'stateboard'
#  'department of pre-university education'
#  'state board of technical eduction panchkula'
#  'maharashtra state(latur board)'
#  'department of pre-university education, bangalore'
#  'jharkhand acedemic council' 'msbte' 'state board (jac, ranchi)'
#  'intermediate state board' 'ibe' 'j & k board' 'isc board , new delhi'
#  'bieap' 'central board of secondary education, new delhi'
#  'scte and vt ,orissa' 'board of intermeadiate education' 'msbte pune'
#  'maharashtra board' 'mpbse' 'central board of secondary education'
#  'aligarh muslim university' 'pu' 'mbose'
#  'stjoseph of cluny matrhrsecschool,neyveli,cuddalore district'
#  'karnataka board' 'hsc' 'biec-patna'
#  'intermediate board of andhra pardesh' 'pre university board, karnataka'
#  'ssc' 'kerala university' 'board of secondary education,rajasthan(rbse)'
#  'cgbse' 'state syllabus'
#  'sri kannika parameswari highier secondary school, udumalpet'
#  'sbte, jharkhand' 'uttaranchal state board'
#  'jharkhand acamedic council (ranchi)' 'kerala state hse board'
#  'karnataka pu board' 'dav public school sec 14'
#  'punjab state board of technical education & industrial training, chandigarh'
#  'karnataka state' 'ms board' 'karanataka secondary board'
#  'bright way college, (up board)' 'intermediate board examination'
#  'state board of technical education harayana' 'jkbose' 'biec'
#  'chse,odisha' 'biec patna' 'tn state board' 'pseb'
#  'board of intermediate ap' 'karnataka secondary education' 'pu board'
#  'dav public school,hehal' 'department of pre university education'
#  'karnataka pre university board'
#  'board of intermediate education,andhra pradesh' 'scte&vt'
#  'west bengal council of higher secondary education'
#  'dote (diploma - computer engg)' 'biec,patna' 'karnatak pu board'
#  'dav public school' 'madhya pradesh board' 'maharashtra board, pune'
#  'j&k state board of school education' 'nagpur' 'dte'
#  'board of school education uttarakhand'
#  'maharashtra state board mumbai divisional board' 'cbese' 'chsc'
#  'pre university board' 'uttarakhand board' 'nagpur board'
#  'karnataka pre unversity board' 'lucknow public college'
#  'baord of intermediate education' 'board of intermidiate education,ap'
#  'jharkhand accademic council' 'department of technical education'
#  'st joseph hr sec school' 'board of higher secondary orissa'
#  'stmiras college for girls' 'matriculation'
#  'dept of pre-university education' 'diploma in computers' 'ua'
#  'jyoti nivas' 'scte vt orissa' 'bseb' 'karnataka pre-university board'
#  'sbtet' 'board of intermidiate' 'latur board'
#  'board fo intermediate education, ap' 'bihar' 'state bord' 'cicse'
#  'board of intermediate education, andhra pradesh' 'cbse board'
#  'up(allahabad)' 'andhra pradesh board of secondary education'
#  'higher secondary education' 'chse,orissa' 'nagpur divisional board'
#  'board of intermediate education,ap' 'isc board' 'bihar board'
#  'board of intmediate education ap' 'board of intermediate,ap'
#  'maharashtra state board of secondary & higher secondary education'
#  'bte up' 'cbse,new delhi' 'gshseb' 'hbse' 'narayana junior college'
#  'cgbse raipur' 'uttar pradesh' 'tamil nadu state board' 'aissce' 'wbbhse'
#  'pre-university board' 'tamilnadu higher secondary education board'
#  'intermidiate' 'pune board' 'apbsc' 'uo board'
#  'bihar intermediate education council'
#  'uttaranchal shiksha avam pariksha parishad' 'apbie'
#  'holy cross matriculation hr sec school'
#  'state board of technical education' 'andhra pradesh state board'
#  'pre university board of karnataka' 'tamil nadu state' 'ap board'
#  'up-board'
#  'maharashtra state boar of secondary and higher secondary education'
#  'mpc' 'state board of karnataka' 'boardofintermediate'
#  'bihar intermediate education council, patna'
#  'srv girls higher sec school,rasipuram'
#  'rajasthan board of secondary education' 'karnataka education board'
#  'jharkhand academic council'
#  'west bengal state council of technical education'
#  ' board of intermediate'
#  'diploma ( maharashtra state board of technical education)'
#  'board of school education harayana'
#  'board of intermediate education, ap' 'higher secondary' 'bseb, patna'
#  'council for indian school certificate examination'
#  'punjab state board of technical education & industrial training'
#  'intermediate council patna' 'board of technicaleducation ,delhi'
#  'staae board' 'mp board bhopal' 'puboard' 'andhra board' 'karnataka sslc'
#  'board of technical education' 'dpue' 'latur' 'msbshse,pune'
#  'uttranchal board' 'bsemp' 'gsheb' 'nagpur board,nagpur' 'u p board'
#  'ahsec' 'rajasthan board ajmer' 'pu board ,karnataka' 'apsb' 'hbsc'
#  'himachal pradesh board of school education'
#  'state board - west bengal council of higher secondary education : wbchse'
#  'hse' 'up baord' ' upboard' 'jaswant modern school'
#  'stateboard/tamil nadu' 'board of secondary school of education'
#  'department of pre-university eduction' 'intermideate' 'ssm srsecschool'
#  'pub' 'board of intermediate(bie)' 'kea' 'tamil nadu polytechnic' 'ghseb'
#  'gujarat board' 'pu  board karnataka' 'pre-university' 'psbte'
#  'govt of karnataka department of pre-university education'
#  'karnataka board secondary education' 'upbhsie'
#  'karnataka secondary education board'
#  'state board of technical education and training' 'u p' 'jstb,jharkhand'
#  'bciec,patna' 'certificate for higher secondary education (chse)orissa'
#  'nasik' 'jiec' 'pu board karnataka' 'p u board, karnataka'
#  'science college' 'gseb/technical education board'
#  'karnataka state examination board'
#  'board of secondary education, rajasthan' 'intermedite'
#  'government polytechnic mumbai , mumbai board' 'karnataka pre-university'
#  'nashik board' 'mp-bse' 'board of higher secondary examination, kerala'
#  'state broad' 'higher secondary state certificate'
#  'amravati divisional board' 'madhya pradesh open school'
#  'all india board' 'ks rangasamy institute of technology' 'hsc pune'
#  'bte,delhi' 'up bourd'
#  'board of high school and intermediate education uttarpradesh'
#  'hslc (tamil nadu state board)' 'preuniversity board(karnataka)']
# CollegeID:
# [   44 11473  2795 ...  6970 13208  7919]
# CollegeTier:
# [2 1]
# Degree:
# ['MCA' 'B.Tech/B.E.' 'M.Tech./M.E.' 'M.Sc. (Tech.)']
# Specialization:
# ['computer application' 'electronics and communication engineering'
#  'computer engineering' nan 'electronics and electrical engineering'
#  'computer science & engineering' 'industrial & production engineering'
#  'mechanical engineering' 'information technology' 'biotechnology' 'other'
#  'electronics & instrumentation eng' 'electronics & telecommunications'
#  'electrical engineering' 'electronics engineering'
#  'instrumentation and control engineering'
#  'computer science and technology'
#  'electronics and instrumentation engineering' 'civil engineering'
#  'computer and communication engineering'
#  'applied electronics and instrumentation'
#  'electronics and computer engineering' 'chemical engineering'
#  'information science engineering' 'telecommunication engineering'
#  'metallurgical engineering' 'computer networking'
#  'biomedical engineering' 'computer science' 'instrumentation engineering'
#  'mechatronics' 'automobile/automotive engineering'
#  'mechanical and automation' 'aeronautical engineering'
#  'mechanical & production engineering'
#  'information & communication technology' 'information science'
#  'embedded systems technology' 'power systems and automation'
#  'industrial engineering' 'polymer technology'
#  'electrical and power engineering' 'electronics']
# collegeGPA:
# [72.8  71.   74.1  ... 55.07 75.99 61.85]
# CollegeCityID:
# [   44. 11473.  2795. ...  6970. 13208.  7919.]
# CollegeCityTier:
# [0 1]
# CollegeState:
# ['Uttar Pradesh' 'Tamil Nadu' 'Madhya Pradesh' 'Haryana' 'Karnataka'
#  'Maharashtra' 'Telangana' 'Delhi' 'Orissa' 'West Bengal' 'Gujarat'
#  'Uttarakhand' 'Rajasthan' 'Punjab' 'Kerala' 'Andhra Pradesh' 'Jharkhand'
#  'Assam' 'Chhattisgarh' 'Bihar' 'Himachal Pradesh' 'Sikkim'
#  'Union Territory' 'Jammu and Kashmir' 'Goa' 'Meghalaya']
# GraduationYear:
# [2013 2012 2014 2010 2011 2015 2009 2016 2017    0]
# English:
# [415 555 495 585 675 394 510 695 485 450 515 525 500 580 650 345 645 545
#  630 520 360 465 605 505 430 395 475 575 355 590 565 405 720 380 665 370
#  535 435 640 335 365 455 595 375 615 685 425 350 440 655 295 385 275 445
#  290 770 765 420 544 560 700 730 625 325 490 305 660 334 570 735 530 755
#  524 715 825 265 710 454 805 464 725 315 534 635 404 745 705 780 300 850
#  310 215 554 250 324 180 285 775 255 684 205 800 280 225 830 790 870 240]
# Logical:
# [495 555 595 465 485 475 570 675 450 510 415 525 455 795 470 420 655 665
#  505 520 585 445 405 355 565 435 500 400 460 545 610 530 690 645 640 480
#  515 385 605 375 325 560 305 440 625 315 544 215 535 575 590 425 395 735
#  365 350 620 580 235 540 660 630 670 324 335 695 615 340 554 280 410 680
#  635 345 295 370 390 334 360 285 650 290 300 490 245 404 330 464 195 685
#  240 255 684 270 705 274 310 700 454 394 275 205 265 380 534 674 715]
# Quant:
# [445 280 625 425 485 515 680 725 665 400 575 375 385 595 410 750 435 495
#  675 380 405 825 475 465 605 355 265 500 735 585 554 545 655 390 450 460
#  620 560 455 555 505 415 325 705 454 630 615 565 310 590 320 260 544 525
#  250 335 510 370 440 635 755 395 430 535 650 470 800 150 365 210 745 494
#  195 305 645 570 715 530 780 685 765 235 330 340 464 295 180 760 334 720
#  275 840 695 885 520 740 345 255 524 534 324 795 285 810 225 690 805 684
# %%
pd.set_option('display.max_colwidth', -1)
pd.set_option('max_columns', 40)
(train.describe(include = 'all').iloc[0:1,:])
# Out:
#        Unnamed: 0      ID  Salary JobCity Gender   DOB  10percentage 10board  \
# count  3000.0      3000.0  3000.0  3000    3000   3000  2808.0        3000
#
#        12graduation  12percentage 12board  CollegeID  CollegeTier Degree  \
# count  2555.0        3000.0        3000    3000.0     3000.0       3000
#
#       Specialization  collegeGPA  CollegeCityID  CollegeCityTier CollegeState  \
# count  2848           3000.0      2843.0         3000.0           3000
#
#        GraduationYear  English  Logical   Quant  Domain  ComputerProgramming  \
# count  3000.0          3000.0   3000.0   3000.0  3000.0  3000.0
#
#        ElectronicsAndSemicon  ComputerScience  MechanicalEngg  ElectricalEngg  \
# count  3000.0                 3000.0           3000.0          3000.0
#
#        TelecomEngg  CivilEngg  conscientiousness  agreeableness  extraversion  \
# count  3000.0       3000.0     2749.0             3000.0         3000.0
#
#        nueroticism  openess_to_experience
# count  2544.0       3000.0

# %%
(test.describe(include = 'all').iloc[0:1,:])
# Out:
#        Unnamed: 0     ID JobCity Gender  DOB  10percentage 10board  \
# count  998.0       998.0  998     998    998  950.0         998
#
#        12graduation  12percentage 12board  CollegeID  CollegeTier Degree  \
# count  843.0         998.0         998     998.0      998.0        998
#
#       Specialization  collegeGPA  CollegeCityID  CollegeCityTier CollegeState  \
# count  950            998.0       955.0          998.0            998
#
#        GraduationYear  English  Logical  Quant  Domain  ComputerProgramming  \
# count  998.0           998.0    998.0    998.0  998.0   998.0
#
#        ElectronicsAndSemicon  ComputerScience  MechanicalEngg  ElectricalEngg  \
# count  998.0                  998.0            998.0           998.0
#
#        TelecomEngg  CivilEngg  conscientiousness  agreeableness  extraversion  \
# count  998.0        998.0      901.0              998.0          998.0
#
#        nueroticism  openess_to_experience
# count  842.0        998.0

# %% [markdown]
# ### Sex

# %%
print("no. of male = " + str((train['Gender']=='m').sum()) +  "\n no. of female = " + str((train['Gender']=='f').sum()))
sex_distribution = train.pivot_table(index= "Gender"  , values= "Salary")
print(sex_distribution)
train['Gender'] = train['Gender'].map({'f': 0 , 'm':1})            #0 for female
test['Gender'] = test['Gender'].map({'f': 0 , 'm':1})              #1 for male
sex_distribution.plot.bar()
plt.ylabel('Salary')
# Out:
# no. of male = 2288
#  no. of female = 712
#                Salary
# Gender
# f       297942.415730
# m       306874.562937
# Text(0, 0.5, 'Salary')

# %% [markdown]
# ### Date of birth/Age

# %%
#plt.plot(train[['DOB' , 'Salary']].sort_values('DOB')['DOB'], train[['DOB' , 'Salary']].sort_values('DOB')['Salary'])
#plt.xlabel("DOB")
#plt.ylabel("salary")

# %%
#train[['DOB' , 'Salary']].sort_values('DOB')

# %%
year = lambda x: datetime.strptime(x, "%Y-%m-%d" ).year
temp = train['DOB'].map(year)
temp_test = test['DOB'].map(year)

age = 2020 - temp
age_test = 2020 - temp_test

train['age'] = age
test['age'] = age_test

test = test.drop(columns=['DOB'])
train = train.drop(columns=['DOB'])

plt.plot(train.sort_values('age')['age'], train.sort_values('age')['Salary'])
plt.ylabel('Salary')
plt.xlabel('age')
#train['age'].plot.hist(alpha=0.5, color = 'red', bins=50)
# Out:
# Text(0.5, 0, 'age')

# %%
age_distribution = train.pivot_table(index= "Salary"  , values= "age")
age_distribution.plot()
plt.ylabel('age')
# Out:
# Text(0, 0.5, 'age')

# %% [markdown]
# ### 10percentage

# %%
print(train['10percentage'].describe())
plt.plot(train.sort_values('10percentage')['10percentage'], train.sort_values('10percentage')['Salary'])
print("nan_values= " +str((train['10percentage'].isna()).sum()))
train['10percentage'] = train['10percentage'].fillna(train['10percentage'].mean())
test['10percentage'] = test['10percentage'].fillna(test['10percentage'].mean())
plt.plot(train.sort_values('10percentage')['10percentage'], train.sort_values('10percentage')['Salary'])
# Out:
# count    2808.000000
# mean     77.942372
# std      9.889565
# min      43.000000
# 25%      71.575000
# 50%      79.330000
# 75%      85.670000
# max      97.760000
# Name: 10percentage, dtype: float64
# nan_values= 192

# %% [markdown]
# ### Degree

# %%
#print(train['Degree'].unique())
categorizer = LabelEncoder()
train['Degree']= categorizer.fit_transform(train['Degree'])
test['Degree']= categorizer.transform(test['Degree'])

# %% [markdown]
# ### conscientiousness, nueroticism;

# %%
train['conscientiousness']= train['conscientiousness'].fillna(train['conscientiousness'].mean())
test['conscientiousness']= test['conscientiousness'].fillna(test['conscientiousness'].mean())

# %%
train['nueroticism']= train['nueroticism'].fillna(train['nueroticism'].mean())
test['nueroticism']= test['nueroticism'].fillna(test['nueroticism'].mean())

# %%
train['nueroticism'].plot.hist(bins=50)

# %% [markdown]
# ### CollegeState

# %%
categorizer1 = LabelEncoder()
train['CollegeState']= categorizer1.fit_transform(train['CollegeState'])
test['CollegeState']= categorizer1.transform(test['CollegeState'])

# %% [markdown]
# college_distribution = train.pivot_table(index= "CollegeID"  , values= "Salary")
# college_distribution.plot.bar()

# %% [markdown]
# college_distribution.sort_values('Salary', ascending = False)

# %% [markdown]
# college_distribution['CollegeID']

# %%
train['CollegeCityID'] = train['CollegeCityID'].fillna(-1)
test['CollegeCityID'] = test['CollegeCityID'].fillna(-1)

# %% [markdown]
# ### Graduation Year

# %%
train['GraduationYear'].unique()
# Out:
# array([2013, 2012, 2014, 2010, 2011, 2015, 2009, 2016, 2017,    0])

# %%
test['GraduationYear'].unique()
# Out:
# array([2014, 2012, 2013, 2011, 2010, 2015, 2009, 2017, 2007])

# %%
plt.plot(train[train['GraduationYear'] !=0].sort_values('GraduationYear')['GraduationYear'], train[train['GraduationYear'] !=0].sort_values('GraduationYear')['Salary'])

# %%
test['GraduationYear'].value_counts()
# Out:
# 2013    298
# 2014    270
# 2012    217
# 2011    108
# 2010    81
# 2015    18
# 2009    3
# 2017    2
# 2007    1
# Name: GraduationYear, dtype: int64

# %%
test[test['GraduationYear'] ==2007]
# Out:
#      Unnamed: 0    ID    JobCity  Gender  10percentage         10board  \
# 368  3368        3368  Hyderabad  1       83.5          ap state board
#
#      12graduation  12percentage                12board  CollegeID  \
# 368  2003.0        87.3          ap intermediate board  12487
#
#      CollegeTier  Degree          Specialization  collegeGPA  CollegeCityID  \
# 368  2            0       information technology  64.7        12487.0
#
#      CollegeCityTier  CollegeState  GraduationYear  English  Logical  Quant  \
# 368  0                0             2007            425      575      645
#
#      Domain  ComputerProgramming  ElectronicsAndSemicon  ComputerScience  \
# 368 -1.0    -1                   -1                     -1
#
#      MechanicalEngg  ElectricalEngg  TelecomEngg  CivilEngg  \
# 368 -1              -1              -1           -1
#
#      conscientiousness  agreeableness  extraversion  nueroticism  \
# 368 -1.4992            -0.7863        -2.0131       -0.165692
#
#      openess_to_experience  age
# 368 -0.6035                 34

# %%
train.loc[2007,'GraduationYear'] = 2013
test.loc[368,'GraduationYear'] = 2013

# %%
categorizer2 = LabelEncoder()
train['GraduationYear']= categorizer2.fit_transform(train['GraduationYear'])
test['GraduationYear']= categorizer2.transform(test['GraduationYear'])

# %% [markdown]
# ### College GPA

# %%
index = train[train['collegeGPA']<=10].index.tolist()
index1 = test[test['collegeGPA']<=10].index.tolist()

# %%
train.loc[index, 'collegeGPA'] = train.loc[index, 'collegeGPA']*9.6
test.loc[index1, 'collegeGPA'] = test.loc[index1, 'collegeGPA']*9.6

# %%
(train['collegeGPA'] == 0).sum()
# Out:
# 0

# %% [markdown]
# ### 12 graduation

# %%
train['12graduation'] = train['12graduation'].fillna(-1)
test['12graduation'] = test['12graduation'].fillna(-1)

# %%
(test['12graduation'].value_counts())
# Out:
#  2009.0    222
#  2008.0    200
#  2010.0    164
# -1.0       155
#  2007.0    107
#  2006.0    93
#  2005.0    25
#  2004.0    14
#  2011.0    10
#  2003.0    4
#  2012.0    3
#  2002.0    1
# Name: 12graduation, dtype: int64

# %%
(train['12graduation'].value_counts())
# Out:
#  2009.0    665
#  2008.0    603
#  2010.0    459
# -1.0       445
#  2007.0    349
#  2006.0    256
#  2005.0    114
#  2004.0    47
#  2011.0    27
#  2003.0    17
#  2002.0    10
#  2012.0    3
#  2001.0    2
#  1998.0    1
#  1995.0    1
#  2013.0    1
# Name: 12graduation, dtype: int64

# %%
categorizer3 = LabelEncoder()
train['12graduation']= categorizer3.fit_transform(train['12graduation'])
test['12graduation']= categorizer3.transform(test['12graduation'])

# %% [markdown]
# ### 12 boards

# %%
train['12board'].value_counts()
# Out:
# cbse                                           1047
# state board                                    943
# 0                                              269
# icse                                           91
# up board                                       62
#                                                ..
# state board of technical education harayana    1
# pre university board of karnataka              1
# bte,delhi                                      1
# up baord                                       1
# state broad                                    1
# Name: 12board, Length: 282, dtype: int64

# %%
test['12board'].value_counts()
# Out:
# cbse                                                      353
# state board                                               311
# 0                                                         90
# icse                                                      38
# up board                                                  25
#                                                           ..
# rbse (state board)                                        1
# state  board of intermediate education, andhra pradesh    1
# matric board                                              1
# maharashtra satate board                                  1
# mp                                                        1
# Name: 12board, Length: 110, dtype: int64

# %%
plt.scatter(train['12board'], train['Salary'])

# %%
index3 = train[train['12board']== 'board of intermediate'].index.tolist()
train.loc[index3, '12board'] = 'board of intermediate education'
index4 = test[test['12board']== 'board of intermediate'].index.tolist()
test.loc[index4, '12board'] = 'board of intermediate education'

index5 = train[train['12board']== 'central board of secondary education'].index.tolist()
train.loc[index5, '12board'] = 'cbse'
index6 = test[test['12board']== 'central board of secondary education'].index.tolist()
test.loc[index6, '12board'] = 'cbse'

index7 =  train[train['12board'].isin(['up', 'u p board'])].index.tolist()
train.loc[index7, '12board'] = 'up board'
index8 =  test[test['12board'].isin(['up', 'u p board'])].index.tolist()
test.loc[index8, '12board'] = 'up board'

index9 = train[train['12board'].isin(['up board', 'cbse', 'state board', 'icse', 'isc','board of intermediate education', '0', 'rbse', 'chse' , 'wbchse', 'ipe', 'bie', 'intermediate' ])].index
index10 = train.index
index11 = [x for x in index10 if x not in index9]
train.loc[index11, '12board'] = 'state board'

index12 = test[test['12board'].isin(['up board', 'cbse', 'state board', 'icse', 'isc','board of intermediate education', '0', 'rbse', 'chse' , 'wbchse', 'ipe', 'bie', 'intermediate' ])].index
index13 = test.index
index14 = [x for x in index13 if x not in index12]
test.loc[index14, '12board'] = 'state board'

categorizer5 = LabelEncoder()
train['12board']= categorizer5.fit_transform(train['12board'])
test['12board']= categorizer5.transform(test['12board'])

# %% [markdown]
# ### 10 boards

# %%
train['10board'].value_counts()
# Out:
# cbse                                              1033
# state board                                       874
# 0                                                 265
# icse                                              211
# ssc                                               91
#                                                   ..
# bright way college, (up board)                    1
# jharkhand secondary examination board (ranchi)    1
# apssc                                             1
# nagpur divisional board                           1
# maharashtra board, pune                           1
# Name: 10board, Length: 226, dtype: int64

# %%
test['10board'].value_counts()
# Out:
# cbse                                                  362
# state board                                           290
# 0                                                     85
# icse                                                  70
# ssc                                                   31
#                                                       ..
# state board of secondary education, andhra pradesh    1
# board of secondary education,orissa                   1
# karnataka secondary eduction                          1
# karnataka state board                                 1
# kseeb                                                 1
# Name: 10board, Length: 98, dtype: int64

# %%
index17 = train[train['10board'].isin(['central board of secondary education','board of secondary education' ])].index.tolist()
train.loc[index17, '10board'] = 'cbse'
index18 = test[test['10board']== 'central board of secondary education'].index.tolist()
test.loc[index18, '10board'] = 'cbse'

index19 =  train[train['10board'].isin(['up', 'u p board', 'up bord', 'uttar pradesh board','uttar pradesh', 'upboard'])].index.tolist()
train.loc[index19, '10board'] = 'up board'
index20 =  test[test['10board'].isin(['up', 'u p board', 'up bord', 'uttar pradesh board','uttar pradesh', 'upboard'])].index.tolist()
test.loc[index20, '10board'] = 'up board'

index21 = train[train['10board'].isin(['up board', 'cbse', 'icse','sslc','state board','0', 'rbse', 'chse' , 'wbchse', 'ipe', 'bie', 'kseeb', 'intermediate' ])].index
index22 = train.index
index23 = [x for x in index22 if x not in index21]
train.loc[index23, '10board'] = 'state board'

index24 = test[test['10board'].isin(['up board', 'cbse', 'state board', 'icse', 'isc', '0', 'rbse', 'chse' , 'wbchse', 'ipe', 'bie', 'intermediate' ])].index
index25 = test.index
index26 = [x for x in index25 if x not in index24]
test.loc[index26, '10board'] = 'state board'

categorizer6 = LabelEncoder()
train['10board']= categorizer6.fit_transform(train['10board'])
test['10board']= categorizer6.transform(test['10board'])

# %% [markdown]
# ### Job City

# %%
# print("unique cities = "+ str(train ['JobCity'].unique().size))
# jobCity_distribution = train.pivot_table(index= "JobCity"  , values= "Salary")
# print(jobCity_distribution.sort_values('Salary'))
# plt.figure(figsize = (20,20))
# jobCity_distribution.plot.bar()

# %%
train['JobCity'].value_counts()
# Out:
# Bangalore       486
# -1              347
# Noida           264
# Hyderabad       236
# Pune            216
#                ...
# Gandhi Nagar    1
# Johannesburg    1
# Jhajjar         1
# Miryalaguda     1
# thane           1
# Name: JobCity, Length: 277, dtype: int64

# %%
# test['JobCity'].value_counts()

# %%
train['JobCity'] = train['JobCity'].str.lower()
train['JobCity'] = train['JobCity'].str.strip()
test['JobCity'] = test['JobCity'].str.lower()
train['JobCity'] = train['JobCity'].str.strip()
#train['JobCity'].value_counts()

# %%
index29 =  train[train['JobCity'].isin(['bangalore', 'banglore' 'bengaluru'])].index.tolist()
train.loc[index29, 'JobCity'] = 'bangalore'
index30 =  test[test['JobCity'].isin(['bangalore ', 'banglore', 'bengaluru'])].index.tolist()
test.loc[index30, 'JobCity'] = 'bangalore'

index31 = train[train['JobCity'].isin(['bangalore', 'noida', '-1','hyderabad','pune','chennai', 'gurgaon', 'new delhi' , 'mumbai', 'kolkata', 'jaipur', 'mysore', 'lucknow', 'navi mumbai', 'bhubaneshwar', 'chandigarh', 'greater noida', 'indore', 'delhi', 'coimbatore', 'bhopal', 'ahmedabad', 'faridabad', 'kochi/cochin', 'mangalore', 'mohali', 'nagpur', 'ghaziabad', 'trivandrum', 'kanpur', 'bhubaneshwar', 'thane', 'patna', 'vishakapatnam', 'dehradun', 'jabalpur', 'pondicherry', 'jodhpur','thiruvananthapuram','raipur', 'nasikity', 'bilaspur', 'gurgaon', 'ranchi' , 'trichy', 'haridwar','madurai', 'aurangabad','secunderabad'  ])].index
index32 = train.index
index33 = [x for x in index32 if x not in index31]
train.loc[index33, 'JobCity'] = 'other'

index34 = test[test['JobCity'].isin(['bangalore', 'noida', '-1','hyderabad','pune','chennai', 'gurgaon', 'new delhi' , 'mumbai', 'kolkata', 'jaipur', 'mysore', 'lucknow', 'navi mumbai', 'bhubaneshwar', 'chandigarh', 'greater noida', 'indore', 'delhi', 'coimbatore', 'bhopal', 'ahmedabad', 'faridabad', 'kochi/cochin', 'mangalore', 'mohali', 'nagpur', 'ghaziabad', 'trivandrum', 'kanpur', 'bhubaneshwar', 'thane', 'patna', 'vishakapatnam', 'dehradun', 'jabalpur', 'pondicherry', 'jodhpur','thiruvananthapuram','raipur', 'nasikity', 'bilaspur', 'gurgaon', 'ranchi' , 'trichy', 'haridwar','madurai', 'aurangabad','secunderabad'  ])].index
index35 = test.index
index36 = [x for x in index35 if x not in index34]
test.loc[index36, 'JobCity'] = 'other'

categorizer7 = LabelEncoder()
train['JobCity']= categorizer7.fit_transform(train['JobCity'])
test['JobCity']= categorizer7.transform(test['JobCity'])

# %%
test.head()
# Out:
#    Unnamed: 0    ID  JobCity  Gender  10percentage  10board  12graduation  \
# 0  3000        3000  0        1       82.200000     1        0
# 1  3001        3001  17       1       81.500000     2        11
# 2  3002        3002  35       1       74.180000     6        10
# 3  3003        3003  3        1       77.753758     6        9
# 4  3004        3004  15       1       77.753758     1        9
#
#    12percentage  12board  CollegeID  CollegeTier  Degree  \
# 0  69.80         3        11759      2            0
# 1  83.16         5        436        1            0
# 2  73.00         10       272        2            0
# 3  62.50         10       3716       2            3
# 4  59.20         3        75         2            0
#
#                               Specialization  collegeGPA  CollegeCityID  \
# 0  electronics and communication engineering  62.20       11759.0
# 1  electrical engineering                     71.44       436.0
# 2  electronics and communication engineering  71.19       272.0
# 3  computer application                       75.83       3716.0
# 4  electronics and communication engineering  66.50       75.0
#
#    CollegeCityTier  CollegeState  GraduationYear  English  Logical  Quant  \
# 0  0                24            5               520      560      650
# 1  0                24            5               605      585      580
# 2  0                17            3               355      485      305
# 3  1                11            4               490      410      535
# 4  0                23            3               515      465      625
#
#      Domain  ComputerProgramming  ElectronicsAndSemicon  ComputerScience  \
# 0  0.207392 -1                    260                   -1
# 1  0.661834 -1                   -1                     -1
# 2  0.058793 -1                    200                   -1
# 3  0.486747  445                 -1                      376
# 4  0.538387 -1                    333                   -1
#
#    MechanicalEngg  ElectricalEngg  TelecomEngg  CivilEngg  conscientiousness  \
# 0 -1              -1              -1           -1         -0.050491
# 1 -1               446            -1           -1         -1.595300
# 2 -1              -1               366         -1         -0.881000
# 3 -1              -1              -1           -1         -0.446300
# 4 -1              -1               260         -1         -0.417300
#
#    agreeableness  extraversion  nueroticism  openess_to_experience  age
# 0  0.0459         1.2396        1.920700    -0.2859                 28
# 1 -0.1206        -0.2974       -0.995000    -0.8608                 29
# 2 -0.7473        -1.2148        1.237400    -0.4455                 30
# 3 -0.2871        -0.6048        0.653000    -1.4356                 32
# 4  0.9688         0.6720       -0.165692     0.0284                 30

# %% [markdown]
# ### Specialization

# %%
train['Specialization'] = train['Specialization'].fillna('-1')
test['Specialization'] = test['Specialization'].fillna('-1')
train['Specialization'] = train['Specialization'].str.strip()
test['Specialization'] = test['Specialization'].str.strip()
# (test['Specialization'].isna()).sum()

# %%
test.head()
# Out:
#    Unnamed: 0    ID  JobCity  Gender  10percentage  10board  12graduation  \
# 0  3000        3000  0        1       82.200000     1        0
# 1  3001        3001  17       1       81.500000     2        11
# 2  3002        3002  35       1       74.180000     6        10
# 3  3003        3003  3        1       77.753758     6        9
# 4  3004        3004  15       1       77.753758     1        9
#
#    12percentage  12board  CollegeID  CollegeTier  Degree  \
# 0  69.80         3        11759      2            0
# 1  83.16         5        436        1            0
# 2  73.00         10       272        2            0
# 3  62.50         10       3716       2            3
# 4  59.20         3        75         2            0
#
#                               Specialization  collegeGPA  CollegeCityID  \
# 0  electronics and communication engineering  62.20       11759.0
# 1  electrical engineering                     71.44       436.0
# 2  electronics and communication engineering  71.19       272.0
# 3  computer application                       75.83       3716.0
# 4  electronics and communication engineering  66.50       75.0
#
#    CollegeCityTier  CollegeState  GraduationYear  English  Logical  Quant  \
# 0  0                24            5               520      560      650
# 1  0                24            5               605      585      580
# 2  0                17            3               355      485      305
# 3  1                11            4               490      410      535
# 4  0                23            3               515      465      625
#
#      Domain  ComputerProgramming  ElectronicsAndSemicon  ComputerScience  \
# 0  0.207392 -1                    260                   -1
# 1  0.661834 -1                   -1                     -1
# 2  0.058793 -1                    200                   -1
# 3  0.486747  445                 -1                      376
# 4  0.538387 -1                    333                   -1
#
#    MechanicalEngg  ElectricalEngg  TelecomEngg  CivilEngg  conscientiousness  \
# 0 -1              -1              -1           -1         -0.050491
# 1 -1               446            -1           -1         -1.595300
# 2 -1              -1               366         -1         -0.881000
# 3 -1              -1              -1           -1         -0.446300
# 4 -1              -1               260         -1         -0.417300
#
#    agreeableness  extraversion  nueroticism  openess_to_experience  age
# 0  0.0459         1.2396        1.920700    -0.2859                 28
# 1 -0.1206        -0.2974       -0.995000    -0.8608                 29
# 2 -0.7473        -1.2148        1.237400    -0.4455                 30
# 3 -0.2871        -0.6048        0.653000    -1.4356                 32
# 4  0.9688         0.6720       -0.165692     0.0284                 30

# %%
test.loc[[205,209,788], 'Specialization'] = '-1'

index50 = test[test['Specialization'].isin(['control and instrumentation engineering','internal combustion engine', 'control and instrumentation engineering'])].index.tolist()
test.loc[index50, 'Specialization'] = '-1'

categorizer8 = LabelEncoder()
train['Specialization']= categorizer8.fit_transform(train['Specialization'])
test['Specialization']= categorizer8.transform(test['Specialization'])
# train['Specialization'].value_counts()

# %%
test.head()
# Out:
#    Unnamed: 0    ID  JobCity  Gender  10percentage  10board  12graduation  \
# 0  3000        3000  0        1       82.200000     1        0
# 1  3001        3001  17       1       81.500000     2        11
# 2  3002        3002  35       1       74.180000     6        10
# 3  3003        3003  3        1       77.753758     6        9
# 4  3004        3004  15       1       77.753758     1        9
#
#    12percentage  12board  CollegeID  CollegeTier  Degree  Specialization  \
# 0  69.80         3        11759      2            0       20
# 1  83.16         5        436        1            0       16
# 2  73.00         10       272        2            0       20
# 3  62.50         10       3716       2            3       9
# 4  59.20         3        75         2            0       20
#
#    collegeGPA  CollegeCityID  CollegeCityTier  CollegeState  GraduationYear  \
# 0  62.20       11759.0        0                24            5
# 1  71.44       436.0          0                24            5
# 2  71.19       272.0          0                17            3
# 3  75.83       3716.0         1                11            4
# 4  66.50       75.0           0                23            3
#
#    English  Logical  Quant    Domain  ComputerProgramming  \
# 0  520      560      650    0.207392 -1
# 1  605      585      580    0.661834 -1
# 2  355      485      305    0.058793 -1
# 3  490      410      535    0.486747  445
# 4  515      465      625    0.538387 -1
#
#    ElectronicsAndSemicon  ComputerScience  MechanicalEngg  ElectricalEngg  \
# 0  260                   -1               -1              -1
# 1 -1                     -1               -1               446
# 2  200                   -1               -1              -1
# 3 -1                      376             -1              -1
# 4  333                   -1               -1              -1
#
#    TelecomEngg  CivilEngg  conscientiousness  agreeableness  extraversion  \
# 0 -1           -1         -0.050491           0.0459         1.2396
# 1 -1           -1         -1.595300          -0.1206        -0.2974
# 2  366         -1         -0.881000          -0.7473        -1.2148
# 3 -1           -1         -0.446300          -0.2871        -0.6048
# 4  260         -1         -0.417300           0.9688         0.6720
#
#    nueroticism  openess_to_experience  age
# 0  1.920700    -0.2859                 28
# 1 -0.995000    -0.8608                 29
# 2  1.237400    -0.4455                 30
# 3  0.653000    -1.4356                 32
# 4 -0.165692     0.0284                 30

# %% [markdown]
# ### CollegeID

# %%
# (train['CollegeID'].unique()).size

# %%
# p = test['CollegeID'].value_counts()
# with pd.option_context('display.max_rows', None, 'display.max_columns', None): print(p) # more options can be specified also

# r = train['CollegeID'].value_counts()
# with pd.option_context('display.max_rows', None, 'display.max_columns', None): print(r) # more options can be specified also

# %%
# index100 = r.index[:100]
# index99 = p.index[:100]

# index31 = train[train['CollegeID'].isin(index100)].index
# index32 = train.index
# index33 = [x for x in index32 if x not in index100]
# index50 = [x for x in index32 if x not in index99]
# train.loc[index33, 'CollegeID'] = 1000000
# train.loc[index50, 'CollegeID'] = 1000000

# index31 = test[test['CollegeID'].isin(index100)].index
# index32 = test.index
# index33 = [x for x in index32 if x not in index100]
# index50 = [x for x in index32 if x not in index99]
# test.loc[index33, 'CollegeID'] = 1000000
# test.loc[index50, 'CollegeID'] = 1000000

# categorizer100 = LabelEncoder()
# train['CollegeID']= categorizer7.fit_transform(train['CollegeID'])
# test['CollegeID']= categorizer7.transform(test['CollegeID'])

# %% [markdown]
# ### CollegeCityID

# %%
# (train['CollegeCityID'].unique()).size

# %%
# p = test['CollegeCityID'].value_counts()
# with pd.option_context('display.max_rows', None, 'display.max_columns', None): print(p) # more options can be specified also

# r = train['CollegeCityID'].value_counts()
# with pd.option_context('display.max_rows', None, 'display.max_columns', None): print(r) # more options can be specified also

# index100 = r.index[:100]
# index99 = p.index[:100]

# index31 = train[train['CollegeCityID'].isin(index100)].index
# index32 = train.index
# index33 = [x for x in index32 if x not in index100]
# index50 = [x for x in index32 if x not in index99]
# train.loc[index33, 'CollegeCityID'] = 1000000
# train.loc[index50, 'CollegeCityID'] = 1000000

# index31 = test[test['CollegeCityID'].isin(index100)].index
# index32 = test.index
# index33 = [x for x in index32 if x not in index100]
# index50 = [x for x in index32 if x not in index99]
# test.loc[index33, 'CollegeCityID'] = 1000000
# test.loc[index50, 'CollegeCityID'] = 1000000

# categorizer100 = LabelEncoder()
# train['CollegeCityID']= categorizer7.fit_transform(train['CollegeCityID'])
# test['CollegeCityID']= categorizer7.transform(test['CollegeCityID'])

# %% [markdown]
# ### Drop Columns

# %%
IDtest = test['ID']
train = train.drop(['Unnamed: 0', 'CollegeID', 'CollegeCityID', 'ID',  'ComputerScience', 'MechanicalEngg' , 'ElectricalEngg', 'TelecomEngg', 'CivilEngg' ], axis=1)
test = test.drop(['Unnamed: 0', 'CollegeID', 'CollegeCityID', 'ID', 'ComputerScience', 'MechanicalEngg' , 'ElectricalEngg', 'TelecomEngg', 'CivilEngg' ], axis=1)
# train = train.drop(['Unnamed: 0', 'CollegeID', 'CollegeCityID', 'ID' ], axis=1)
# test = test.drop(['Unnamed: 0', 'CollegeID', 'CollegeCityID', 'ID' ], axis=1)
# train = train.drop(['Unnamed: 0', 'CollegeID', 'CollegeCityID', 'ID', 'MechanicalEngg' , 'ElectricalEngg', 'TelecomEngg', 'CivilEngg' ], axis=1)
# test = test.drop(['Unnamed: 0', 'CollegeID', 'CollegeCityID', 'ID' , 'MechanicalEngg' , 'ElectricalEngg', 'TelecomEngg', 'CivilEngg'], axis=1)

# %%
y_train = train['Salary']
train = train.drop(['Salary'], axis=1)

# train.head()

# %%
train
# Out:
#       JobCity  Gender  10percentage  10board  12graduation  12percentage  \
# 0     3        1       55.5          6        9             52.50
# 1     8        1       83.0          6        0             86.00
# 2     35       1       81.2          1        10            75.40
# 3     34       1       85.0          1        10            68.60
# 4     8        1       89.9          6        0             84.50
# ...  ..       ..        ...         ..       ..               ...
# 2995  34       0       85.6          1        0             87.20
# 2996  8        1       88.6          6        12            74.16
# 2997  34       1       52.0          0        8             55.00
# 2998  7        1       74.6          1        7             80.80
# 2999  3        1       65.0          6        9             50.00
#
#       12board  CollegeTier  Degree  Specialization  collegeGPA  \
# 0     10       2            3       9               72.80
# 1     10       2            0       20              71.00
# 2     3        1            0       10              74.10
# 3     3        2            0       0               64.50
# 4     10       2            0       20              68.00
# ...   ..      ..           ..       ..                ...
# 2995  3        2            0       31              73.00
# 2996  10       2            0       31              73.10
# 2997  0        2            0       10              65.80
# 2998  3        2            0       20              72.45
# 2999  10       2            3       9               73.14
#
#       CollegeCityTier  CollegeState  GraduationYear  English  Logical  Quant  \
# 0     0                23            4               415      495      445
# 1     1                20            4               555      555      280
# 2     0                13            4               495      595      625
# 3     0                7             3               585      465      425
# 4     0                11            4               675      485      485
# ...  ..                ..           ..               ...      ...      ...
# 2995  0                7             4               590      585      705
# 2996  0                20            5               420      445      415
# 2997  0                23            3               395      350      445
# 2998  0                23            1               535      415      635
# 2999  1                11            4               625      495      430
#
#         Domain  ComputerProgramming  ElectronicsAndSemicon  conscientiousness  \
# 0     0.864685  525                 -1                     -0.037404
# 1     0.376060  425                  300                   -0.159000
# 2     0.911395  685                 -1                     -1.020800
# 3     0.450877  395                 -1                     -0.996900
# 4    -1.000000  455                 -1                      1.277200
# ...        ...  ...                 ..                           ...
# 2995  0.622643  515                 -1                     -1.020800
# 2996  0.744758  415                 -1                      0.990000
# 2997  0.276047  345                 -1                     -1.112800
# 2998  0.960603 -1                    466                    0.819200
# 2999  0.793581  495                 -1                     -0.877200
#
#       agreeableness  extraversion  nueroticism  openess_to_experience  age
# 0    -0.6201        -0.1437        0.906600    -1.6273                 30
# 1     0.8784         0.7785        0.145900     1.2470                 30
# 2    -1.1196        -0.6048        0.526200     0.2889                 29
# 3     0.0328        -0.3440        0.708600    -1.2354                 30
# 4     0.8784         0.4711       -0.741500     0.4805                 29
# ...      ...            ...             ...        ...                 ..
# 2995 -0.6201        -0.7585       -0.180071    -1.4356                 29
# 2996  0.3789         0.4711       -1.502100     0.8637                 28
# 2997 -2.6193        -1.0697        1.325500    -1.2354                 30
# 2998  0.3448         1.1074       -0.172700     1.4502                 32
# 2999 -0.6201        -0.4511        0.653000    -0.4776                 31
#
# [3000 rows x 26 columns]

# %%
test
# Out:
#      JobCity  Gender  10percentage  10board  12graduation  12percentage  \
# 0    0        1       82.200000     1        0             69.80
# 1    17       1       81.500000     2        11            83.16
# 2    35       1       74.180000     6        10            73.00
# 3    3        1       77.753758     6        9             62.50
# 4    15       1       77.753758     1        9             59.20
# ..   ..      ..             ...    ..       ..               ...
# 993  35       1       69.000000     6        8             51.30
# 994  38       1       83.460000     6        10            61.83
# 995  17       1       86.340000     6        11            83.70
# 996  34       1       79.600000     1        11            73.20
# 997  3        1       91.200000     1        7             81.20
#
#      12board  CollegeTier  Degree  Specialization  collegeGPA  \
# 0    3        2            0       20              62.20
# 1    5        1            0       16              71.44
# 2    10       2            0       20              71.19
# 3    10       2            3       9               75.83
# 4    3        2            0       20              66.50
# ..  ..       ..           ..       ..                ...
# 993  10       2            0       31              72.00
# 994  10       2            0       31              73.00
# 995  10       2            0       13              72.19
# 996  3        2            0       20              66.96
# 997  3        2            0       10              72.50
#
#      CollegeCityTier  CollegeState  GraduationYear  English  Logical  Quant  \
# 0    0                24            5               520      560      650
# 1    0                24            5               605      585      580
# 2    0                17            3               355      485      305
# 3    1                11            4               490      410      535
# 4    0                23            3               515      465      625
# ..  ..                ..           ..               ...      ...      ...
# 993  0                13            5               430      395      235
# 994  0                14            5               430      435      450
# 995  0                0             4               525      435      620
# 996  1                18            5               535      640      630
# 997  0                23            1               595      565      495
#
#        Domain  ComputerProgramming  ElectronicsAndSemicon  conscientiousness  \
# 0    0.207392 -1                    260                   -0.050491
# 1    0.661834 -1                   -1                     -1.595300
# 2    0.058793 -1                    200                   -0.881000
# 3    0.486747  445                 -1                     -0.446300
# 4    0.538387 -1                    333                   -0.417300
# ..        ... ..                    ...                         ...
# 993  0.744758  455                 -1                     -0.015400
# 994  0.953900  535                 -1                      0.702700
# 995  0.486747  445                 -1                      0.990000
# 996  0.338786 -1                    292                   -1.164400
# 997  0.884123  535                 -1                      0.046400
#
#      agreeableness  extraversion  nueroticism  openess_to_experience  age
# 0    0.0459         1.2396        1.920700    -0.2859                 28
# 1   -0.1206        -0.2974       -0.995000    -0.8608                 29
# 2   -0.7473        -1.2148        1.237400    -0.4455                 30
# 3   -0.2871        -0.6048        0.653000    -1.4356                 32
# 4    0.9688         0.6720       -0.165692     0.0284                 30
# ..      ...            ...             ...        ...                 ..
# 993 -1.2861         0.0100        0.272700    -0.4776                 33
# 994  0.3789         0.3174       -1.121800     0.4805                 30
# 995  1.0449         1.8543        0.019200     0.0973                 29
# 996  0.2124         0.3174        0.906600    -0.4776                 29
# 997  0.6568         0.5269       -0.642800    -0.9194                 33
#
# [998 rows x 26 columns]

# %% [markdown]
# # TRAINING MODEL

# %%
from sklearn.linear_model import ElasticNet, Lasso,  BayesianRidge, LassoLarsIC
from sklearn.ensemble import RandomForestRegressor,  GradientBoostingRegressor
from sklearn.kernel_ridge import KernelRidge
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import RobustScaler
from sklearn.base import BaseEstimator, TransformerMixin, RegressorMixin, clone
from sklearn.model_selection import KFold, cross_val_score, train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler
from sklearn import preprocessing
import xgboost as xgb
import lightgbm as lgb
from sklearn.metrics import accuracy_score

# %%
# X_train, X_test, Y_train, Y_test = train_test_split(train, y_train, test_size =0.2, random_state = 42)
# X_train

# scalar = StandardScaler()
# X_train=scalar.fit_transform(X_train)
# X_test=scalar.transform(X_test)
# test =scalar.transform(test)
# test


# test



# model = xgb.XGBRegressor(objective='reg:squarederror')
# model.fit(X_train, Y_train)
# p = model.predict(X_test)
# q =  model.predict(test)

# p

# Y_test.values

# q

# final = pd.DataFrame()
# final['ID'] = IDtest
# final['Salary'] = q

# model.score(X_test, Y_test)

# final_csv = final.to_csv("final.csv", index=False)

# %%
# final.dtypes

# %%
scalar = StandardScaler()
X = scalar.fit_transform(train)
y = y_train.values
test =scalar.transform(test)
test
# Out:
# array([[-1.308754  ,  0.557843  ,  0.4450717 , ...,  2.29725328,
#         -0.1394303 , -0.88878501],
#        [-0.09474065,  0.557843  ,  0.37189711, ..., -0.89114784,
#         -0.70816651, -0.33120345],
#        [ 1.19068525,  0.557843  , -0.39330001, ...,  1.55004524,
#         -0.29731915,  0.22637811],
#        ...,
#        [-0.09474065,  0.557843  ,  0.87784712, ...,  0.21790879,
#          0.23966123, -0.33120345],
#        [ 1.1192727 ,  0.557843  ,  0.17328037, ...,  1.18830601,
#         -0.32907499, -0.33120345],
#        [-1.09451635,  0.557843  ,  1.38588783, ..., -0.50600709,
#         -0.76613823,  1.89912279]])

# %%
y.shape
# Out:
# (3000,)

# %%
#Validation function
n_folds = 5

def rmsle_cv(model):
    kf = KFold(n_folds, shuffle=True, random_state=42).get_n_splits(train.values)
    rmse= np.sqrt(-cross_val_score(model, X, y, scoring="neg_mean_squared_error", cv = kf))
    return(rmse)

# %%
lasso = make_pipeline(RobustScaler(), Lasso(alpha =0.0005, random_state=1))
ENet = make_pipeline(RobustScaler(), ElasticNet(alpha=0.0005, l1_ratio=.9, random_state=3))
KRR = KernelRidge(alpha=0.6, kernel='polynomial', degree=2, coef0=2.5)
GBoost = GradientBoostingRegressor(n_estimators=3000, learning_rate=0.05,
                                   max_depth=4, max_features='sqrt',
                                   min_samples_leaf=15, min_samples_split=10, 
                                   loss='huber', random_state =5)
model_xgb = xgb.XGBRegressor(colsample_bytree=0.4603, gamma=0.0468, 
                             learning_rate=0.05, max_depth=3, 
                             min_child_weight=1.7817, n_estimators=2200,
                             reg_alpha=0.4640, reg_lambda=0.8571,
                             subsample=0.5213, silent=1,
                             random_state =7, nthread = -1)
model_lgb = lgb.LGBMRegressor(objective='regression',num_leaves=5,
                              learning_rate=0.05, n_estimators=720,
                              max_bin = 55, bagging_fraction = 0.8,
                              bagging_freq = 5, feature_fraction = 0.2319,
                              feature_fraction_seed=9, bagging_seed=9,
                              min_data_in_leaf =6, min_sum_hessian_in_leaf = 11)

# %%
score = rmsle_cv(lasso)
print("\nLasso score: {:.4f} ({:.4f})\n".format(score.mean(), score.std()))

score = rmsle_cv(ENet)
print("ElasticNet score: {:.4f} ({:.4f})\n".format(score.mean(), score.std()))

score = rmsle_cv(KRR)
print("Kernel Ridge score: {:.4f} ({:.4f})\n".format(score.mean(), score.std()))

score = rmsle_cv(GBoost)
print("Gradient Boosting score: {:.4f} ({:.4f})\n".format(score.mean(), score.std()))

score = rmsle_cv(model_xgb)
print("Xgboost score: {:.4f} ({:.4f})\n".format(score.mean(), score.std()))

score = rmsle_cv(model_lgb)
print("LGBM score: {:.4f} ({:.4f})\n" .format(score.mean(), score.std()))



class AveragingModels(BaseEstimator, RegressorMixin, TransformerMixin):
    def __init__(self, models):
        self.models = models

    def fit(self, X, y):
        self.models_ = [clone(x) for x in self.models]
        
        for model in self.models_:
            model.fit(X, y)

        return self

    def predict(self, X):
        predictions = np.column_stack([
            model.predict(X) for model in self.models_
        ])
        return np.mean(predictions, axis=1)  

averaged_models = AveragingModels(models = (ENet, GBoost, KRR, lasso))

score = rmsle_cv(averaged_models)
print(" Averaged base models score: {:.4f} ({:.4f})\n".format(score.mean(), score.std()))
# Out:
# Lasso score: 175410.9998 (25453.1090)
#
# ElasticNet score: 175410.5322 (25452.6548)
#
# Kernel Ridge score: 184854.6475 (22431.6784)
#
# Gradient Boosting score: 178683.9768 (21710.3173)
#
# Xgboost score: 189002.6226 (24628.0224)
#
# LGBM score: 178726.0099 (23881.9320)
#
#  Averaged base models score: 174873.7125 (24228.1715)

# %%
class StackingAveragedModels(BaseEstimator, RegressorMixin, TransformerMixin):
    def __init__(self, base_models, meta_model, n_folds=5):
        self.base_models = base_models
        self.meta_model = meta_model
        self.n_folds = n_folds

    def fit(self, X, y):
        self.base_models_ = [list() for x in self.base_models]
        self.meta_model_ = clone(self.meta_model)
        kfold = KFold(n_splits=self.n_folds, shuffle=True, random_state=156)
        
        out_of_fold_predictions = np.zeros((X.shape[0], len(self.base_models)))
        for i, model in enumerate(self.base_models):
            for train_index, holdout_index in kfold.split(X, y):
                instance = clone(model)
                self.base_models_[i].append(instance)
                instance.fit(X[train_index], y[train_index])
                y_pred = instance.predict(X[holdout_index])
                out_of_fold_predictions[holdout_index, i] = y_pred
                
        self.meta_model_.fit(out_of_fold_predictions, y)
        return self
   
    def predict(self, X):
        meta_features = np.column_stack([
            np.column_stack([model.predict(X) for model in base_models]).mean(axis=1)
            for base_models in self.base_models_ ])
        return self.meta_model_.predict(meta_features)

# %%
stacked_averaged_models = StackingAveragedModels(base_models = (ENet, GBoost, KRR),
                                                 meta_model = lasso)

score = rmsle_cv(stacked_averaged_models)
print("Stacking Averaged models score: {:.4f} ({:.4f})".format(score.mean(), score.std()))
# Out:
# Stacking Averaged models score: 174565.7249 (24856.7800)

# %%
def rmsle(y, y_pred):
    return np.sqrt(mean_squared_error(y, y_pred))

# %%
stacked_averaged_models.fit(X, y)
stacked_train_pred = stacked_averaged_models.predict(X)
stacked_pred = stacked_averaged_models.predict(test)
print(rmsle(y, stacked_train_pred))
# Out:
# 156527.78765690938

# %%
model_xgb.fit(X, y)
xgb_train_pred = model_xgb.predict(X)
xgb_pred = model_xgb.predict(test)
print(rmsle(y, xgb_train_pred))
# Out:
# 66262.72138839134

# %%
model_lgb.fit(X, y)
lgb_train_pred = model_lgb.predict(X)
lgb_pred = model_lgb.predict(test)
print(rmsle(y, lgb_train_pred))
# Out:
# 132709.6551996566

# %%
print('RMSLE score on train data:')
print(rmsle(y_train,stacked_train_pred*0.70 +
               xgb_train_pred*0.15 + lgb_train_pred*0.15 ))
# Out:
# RMSLE score on train data:
# 135863.0926860028

# %%
ensemble = stacked_pred*0.70 + xgb_pred*0.15 + lgb_pred*0.15
ensemble
# Out:
# array([255960.20001873, 397707.32738216, 211505.3896412 , 262437.50574706,
#        316382.93001041, 300109.29297221, 437454.16709948, 392847.56252186,
#        164423.43999736, 442524.28836913, 321279.0750804 , 381463.95980803,
#        271313.28693292, 240496.82161363, 115792.50410318, 265789.72948217,
#        439753.47968735, 454081.46134099, 254741.29002155, 315397.94775262,
#        245773.04503451, 334216.2485866 , 291982.04811416, 262009.47640773,
#        425398.075439  , 322128.00347642, 449702.55024049, 172028.79985629,
#        353497.2736215 , 255572.82951544, 217197.07922034, 335513.90722522,
#        434641.67169592, 392339.98150523, 262044.0925638 , 255120.22784813,
#        303656.52447659, 330303.8241523 , 258227.44967924, 245663.63538519,
#        117614.51423936, 254981.69233518, 188992.47125933, 288833.72676732,
#        408133.61062912, 355335.62103605, 444816.94250209, 358721.90831885,
#        266642.39472355, 377774.82707891, 257573.62423869, 243161.76240633,
#        262409.88585672, 607126.17797741, 387401.64929773, 405882.14404966,
#        283941.32609331, 248863.44072541, 321442.66620858, 348312.03268113,
#        340870.83306703, 181187.13276629, 413947.53248386, 242957.36974837,
#        189172.59721194, 294229.50692769, 275547.3161847 , 216721.33346507,
#        301279.62982864, 199460.72631093, 321686.02854503, 247269.72873476,
#        325865.91284451, 337941.42303485, 349575.42333106, 345633.00939482,
#        355799.31485164, 400621.72210234, 389143.08982606, 244072.04033607,
#        294299.96177952, 384836.35543873, 290582.03982377, 122708.06750481,
#        329136.13293629, 344737.93849819, 385828.1725119 , 472794.82786788,
#        318173.00304978, 302056.90025742, 193771.9230053 , 276331.94035306,
#        426856.95141923, 413753.90967225, 240205.7724449 , 331734.29120009,
#        177922.26327424, 335352.05661292, 296120.07670102, 319789.16742354,
#        353955.36170297, 433643.03293181, 202169.97336654, 369717.25243725,
#        368740.99863265, 197268.4434354 , 299839.80446639, 170125.61497479,
#        277274.51352318, 238615.97525215, 542386.89248186, 370838.90021668,
#        402997.49636146, 164430.72436702, 414170.87645332, 351515.7630511 ,
#        233560.15598358, 365871.80675706, 255728.78794745, 409866.35268088,
#        446506.63982989, 366847.7762251 , 301929.59894283, 403519.14277854,
